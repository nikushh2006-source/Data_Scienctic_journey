# %%
# plt.hist(data ,bins =number_of_bins,color ='color_name',coloredge='black')
import matplotlib.pyplot as plt
score =[100,93,82,73,60,55,47,37,20,15,0,53,64,74,84,97,100,88,75,65,55,45,35,25,15,5]

plt.hist(score,bins=6,color='green' ,edgecolor = 'black')
plt.title('Score distribution of students')
plt.xlabel('Scores')
plt.ylabel('Number of students')
plt.show()
